# %% [markdown]
# <a href="https://colab.research.google.com/github/JoseSergio414/Projeto-Integrador-II/blob/main/PROJETOII_dados_finais_expfinal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Cadeia Automotiva dados finais exportação

# %%
import pandas as pd

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
origem = '/content/drive/MyDrive/Data/COMEXSTAT/'

# %%
arquivo_1 = origem + 'dado_exp_final.csv'

# %%
expfinal = pd.read_csv(arquivo_1,low_memory=False,sep=',',encoding='UTF-8')

# %%
expfinal = expfinal.rename(columns={'TOTAL IMPORTADO': 'TOTAL EXPORTADO'})

# %%
expfinal = expfinal.rename(columns={'KG_LIQUIDO': 'TOTAL KGL EXP.'})

# %%
expfinal.head(5)
# Out:
#    CO_ANO  CO_MES  CO_PAIS SG_UF_MUN   CO_MUN  TOTAL KGL EXP.  \
# 0    2021       3      493        SP  3434401             966
# 1    2021       7      386        SP  3409502               1
# 2    2021      12       63        PR  4106902              73
# 3    2021       7      586        SC  4202909              75
# 4    2021       8       63        SP  3440002            6949
#
#    TOTAL EXPORTADO  CO_SH4                                         NO_SH4_POR  \
# 0             7788    3305                              Preparações capilares
# 1             1544    8419  Aparelhos e dispositivos, mesmo aquecidos elec...
# 2              907    8511  Aparelhos e dispositivos elétricos de ignição ...
# 3             3942    6204  Fatos de saia-casaco, conjuntos, casacos, vest...
# 4            29604    8708  Partes e acessórios dos veículos automóveis da...
#
#   NO_MUN_MIN    NO_PAIS
# 0     Osasco     México
# 1   Campinas     Itália
# 2   Curitiba  Argentina
# ...

# %%
expfinal.head()
# Out:
#    CO_ANO  CO_MES  CO_PAIS SG_UF_MUN   CO_MUN  TOTAL KGL EXP.  \
# 0    2021       3      493        SP  3434401             966
# 1    2021       7      386        SP  3409502               1
# 2    2021      12       63        PR  4106902              73
# 3    2021       7      586        SC  4202909              75
# 4    2021       8       63        SP  3440002            6949
#
#    TOTAL EXPORTADO  CO_SH4                                         NO_SH4_POR  \
# 0             7788    3305                              Preparações capilares
# 1             1544    8419  Aparelhos e dispositivos, mesmo aquecidos elec...
# 2              907    8511  Aparelhos e dispositivos elétricos de ignição ...
# 3             3942    6204  Fatos de saia-casaco, conjuntos, casacos, vest...
# 4            29604    8708  Partes e acessórios dos veículos automóveis da...
#
#   NO_MUN_MIN    NO_PAIS
# 0     Osasco     México
# 1   Campinas     Itália
# 2   Curitiba  Argentina
# ...

# %%
expfinal.tail(5)
# Out:
#          CO_ANO  CO_MES  CO_PAIS SG_UF_MUN   CO_MUN  TOTAL KGL EXP.  \
# 5811674    2026       2       63        SP  3430607              35
# 5811675    2026       1      361        RS  4316808             518
# 5811676    2026       1       63        RS  4302105             266
# 5811677    2026       1      741        RJ  3304524               8
# 5811678    2026       2      580        RS  4309308               0
#
#          TOTAL EXPORTADO  CO_SH4  \
# 5811674             4944    2849
# 5811675            41461    4813
# 5811676              533    1902
# 5811677              627    8907
# 5811678               73    8541
#
#                                                 NO_SH4_POR         NO_MUN_MIN  \
# 5811674  Carbonetos de constituição química definida ou...    Mogi das Cruzes
# 5811675  Papel para cigarros, mesmo cortado nas dimensõ...  Santa Cruz do Sul
# 5811676  Massas alimentícias, mesmo cozidas ou recheada...    Bento Gonçalves
# ...

# %%
print(expfinal.columns)
# Out:
# Index(['CO_ANO', 'CO_MES', 'CO_PAIS', 'SG_UF_MUN', 'CO_MUN', 'TOTAL KGL EXP.',
#        'TOTAL EXPORTADO', 'CO_SH4', 'NO_SH4_POR', 'NO_MUN_MIN', 'NO_PAIS'],
#       dtype='object')

# %%
expfinal.to_csv(origem+'dado_exp_final.csv',index=False)
