# %% [markdown]
# <a href="https://colab.research.google.com/github/JoseSergio414/Projeto-Integrador-II/blob/main/PROJETOII_dados_finais_impfinal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Cadeia Automotiva dados finais importação

# %%
import pandas as pd

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
origem = '/content/drive/MyDrive/Data/COMEXSTAT/'

# %%
arquivo_1 = origem + 'dado_imp_final1.csv'

# %%
impfinal = pd.read_csv(arquivo_1,low_memory=False,sep=',',encoding='UTF-8')

# %%
impfinal = impfinal.rename(columns={'VL_FOB': 'TOTAL IMPORTADO'})

# %%
impfinal = impfinal.rename(columns={'KG_LIQUIDO': 'TOTAL KGL IMP.'})

# %%
impfinal.head(5)
# Out:
#    CO_ANO  CO_MES  CO_PAIS SG_UF_MUN   CO_MUN  TOTAL KGL IMP.  \
# 0    2021       7       23        SP  3416200            3668
# 1    2021       4      160        SP  3424709               1
# 2    2021       7      160        SP  3409205            5043
# 3    2021       1      249        SP  3420509           10417
# 4    2021      11      160        SP  3450308          306224
#
#    TOTAL IMPORTADO  CO_SH4                                         NO_SH4_POR  \
# 0            11688    4115  Couro reconstituído à base de couro ou de fibr...
# 1             3685    8525  Aparelhos emissores (transmissores) para radio...
# 2            45918    8302  Guarnições, ferragens e artigos semelhantes, d...
# 3           207124    4009  Tubos de borracha vulcanizada não endurecida, ...
# 4          3298907    8536  Aparelhos para interrupção, seccionamento, pro...
#
#    NO_MUN_MIN         NO_PAIS
# 0      Franca        Alemanha
# 1  Jaguariúna           China
# ...

# %%
impfinal.head()
# Out:
#    CO_ANO  CO_MES  CO_PAIS SG_UF_MUN   CO_MUN  TOTAL KGL IMP.  \
# 0    2021       7       23        SP  3416200            3668
# 1    2021       4      160        SP  3424709               1
# 2    2021       7      160        SP  3409205            5043
# 3    2021       1      249        SP  3420509           10417
# 4    2021      11      160        SP  3450308          306224
#
#    TOTAL IMPORTADO  CO_SH4                                         NO_SH4_POR  \
# 0            11688    4115  Couro reconstituído à base de couro ou de fibr...
# 1             3685    8525  Aparelhos emissores (transmissores) para radio...
# 2            45918    8302  Guarnições, ferragens e artigos semelhantes, d...
# 3           207124    4009  Tubos de borracha vulcanizada não endurecida, ...
# 4          3298907    8536  Aparelhos para interrupção, seccionamento, pro...
#
#    NO_MUN_MIN         NO_PAIS
# 0      Franca        Alemanha
# 1  Jaguariúna           China
# ...

# %%
impfinal.tail(5)
# Out:
#          CO_ANO  CO_MES  CO_PAIS SG_UF_MUN   CO_MUN  TOTAL KGL IMP.  \
# 8581655    2026       2      351        SC  4208906            1412
# 8581656    2026       2       72        GO  5303203               0
# 8581657    2026       2      603        BA  2905701               3
# 8581658    2026       1       81        SC  4205407           15261
# 8581659    2026       1      351        SP  3425904             419
#
#          TOTAL IMPORTADO  CO_SH4  \
# 8581655           202140    8537
# 8581656              217    8536
# 8581657             1143    8544
# 8581658            76679    6110
# 8581659             6861    6601
#
#                                                 NO_SH4_POR      NO_MUN_MIN  \
# 8581655  Quadros, painéis, consolas, cabinas, armários ...  Jaraguá do Sul
# 8581656  Aparelhos para interrupção, seccionamento, pro...      Barro Alto
# 8581657  Fios, cabos (incluídos os cabos coaxiais) e ou...        Camaçari
# ...

# %%
print(impfinal.columns)
# Out:
# Index(['CO_ANO', 'CO_MES', 'CO_PAIS', 'SG_UF_MUN', 'CO_MUN', 'TOTAL KGL IMP.',
#        'TOTAL IMPORTADO', 'CO_SH4', 'NO_SH4_POR', 'NO_MUN_MIN', 'NO_PAIS'],
#       dtype='object')

# %%
impfinal.to_csv(origem+'dado_imp_final.csv',index=False)
